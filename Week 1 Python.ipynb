# %% [markdown]
# This is a test demo

# %%
print('hello world')

# %%
import random
print(random.randint(0,5))
# Out:
# 3

# %% [markdown]
# Installing 3rd party packages

# %%
import sys
# !{sys.executable} -m pip install {module name}
# Out:
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.0-py3-none-any.whl size=8691 sha256=88a0b889b03dbcbc007171fff1df14db8c2ac547db3f328fae3499ff8ee0e8bd
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e5/5e/f7/441179ddf6ac56f36cb1d84d94f35beedd5da15986ce3d321d
# Successfully built pyperclip
# ...
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# <ipython-input-10-e9c55587bfdd> in <module>
#       3
#       4 import pyperclip
# ----> 5 pyperclip.paste()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyperclip/__init__.py in lazy_load_stub_paste()
#     638     global copy, paste
#     639     copy, paste = determine_clipboard()
# --> 640     return paste()
#     641
#     642
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyperclip/__init__.py in __call__(self, *args, **kwargs)
#     301
#     302         def __call__(self, *args, **kwargs):
# ...
